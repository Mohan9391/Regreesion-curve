# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohan9391/Regreesion-curve/blob/main/commite_curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "distance": [2, 4, 6, 8, 10, 12, 15],
    "time": [10, 15, 22, 28, 35, 42, 50]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    distance  time
# 0         2    10
# 1         4    15
# 2         6    22
# 3         8    28
# 4        10    35
# 5        12    42
# 6        15    50

# %%
X = df[["distance"]]
y = df["time"]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model = LinearRegression()

model.fit(X,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X))

plt.xlabel("Distance (km)")
plt.ylabel("Travel Time (minutes)")
plt.title("My Commute Regression")
plt.show()
